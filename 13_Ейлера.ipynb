# %%
import math
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return x + math.sin(y/math.sqrt(0.3))

x0 = 0.5
b = 1.5
h = 0.1
x = np.arange(x0, b+h, h)
n = len(x) - 1
y = np.empty(n+1)
y[0] = 0.6

for i in range(n):
    y[i+1] = y[i] + f(x[i], y[i]) * h

y_rounded = np.round_(y, 4)

print('x=', x, '\ny=', y_rounded)

plt.plot(x, y, 'o', x, y, 'red')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Метод Ейлера')
plt.legend(['точки', 'x+sin(y/sqrt(0.3))'])
plt.grid()
plt.show()
# Out:
# x= [0.5 0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5]
# y= [0.6    0.7389 0.8965 1.0662 1.2393 1.4063 1.5606 1.6994 1.8233 1.9347
#  2.0366]
